# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pathlib import Path
import pandas as pd
import tensorflow as tf
from sklearn.metrics import classification_report

# %%
# Import data
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lesson_2/datasets/sports-articles.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#        Label  totalWordsCount  semanticobjscore  semanticsubjscore  CC  CD  \
# 0  objective              109                 0                  1   7   9
# 1  objective              309                21                  4   1  19
# 2  objective              149                 6                  1   8  14
# 3  objective              305                18                  5   7  26
# 4  objective              491                23                  8  33  47
#
#    DT  EX  FW  INs  ...  pronouns2nd  pronouns3rd  compsupadjadv  past  \
# 0   0   5   8    6  ...            0            3              0    11
# 1   1   4  35   23  ...            0           10              0    13
# 2   0   5  15   11  ...            0            2              0     8
# 3   0  10  37   21  ...            0            8              3    13
# 4   0  12  61   36  ...            0           16              2    34
#
#    imperative  present3rd  present1st2nd  sentence1st  sentencelast  \
# 0           0           0              0            0             1
# 1           0          14              9            1             1
# 2           0           3              2            1             1
# 3           1           7              1            1             1
# 4           1           5              6            1             1
#
#    txtcomplexity
# 0             18
# 1             14
# 2             18
# 3             20
# 4             24
#
# [5 rows x 60 columns]

# %%
# Drop the label to create the X data
X = df.drop('Label', axis=1)
# Create the y set from the "Label" column
y = df["Label"]

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Encode the y data with the label encoder
# Create an instance of the label encoder
le = LabelEncoder()

# Fit and transform the y training and testing data using the label encoder
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# %%
# Scale the X data by using StandardScaler()
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the deep learning model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=5, activation="tanh", input_dim=len(X_train.columns)))

nn_model.add(tf.keras.layers.Dense(units=3, activation="tanh"))
nn_model.add(tf.keras.layers.Dense(units=9, activation="tanh"))
nn_model.add(tf.keras.layers.Dense(units=3, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train_encoded, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test_encoded,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# /Users/stevenhill/anaconda3/envs/dev/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.5869 - loss: 0.6852
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.7393 - loss: 0.6539
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.7404 - loss: 0.6250
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.7554 - loss: 0.5850
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - accuracy: 0.8160 - loss: 0.5375
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - accuracy: 0.8219 - loss: 0.5032
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - accuracy: 0.8479 - loss: 0.4542
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - accuracy: 0.8418 - loss: 0.4388
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step - accuracy: 0.8580 - loss: 0.4062
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.8420 - loss: 0.4093
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.8484 - loss: 0.4068
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - accuracy: 0.8669 - loss: 0.3784
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.8631 - loss: 0.3763
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.8646 - loss: 0.3791
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.8799 - loss: 0.3547
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.8720 - loss: 0.3600
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.8871 - loss: 0.3418
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - accuracy: 0.8710 - loss: 0.3671
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.8857 - loss: 0.3410
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - accuracy: 0.8789 - loss: 0.3597
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.8902 - loss: 0.3236
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - accuracy: 0.8805 - loss: 0.3411
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.8712 - loss: 0.3678
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.8803 - loss: 0.3626
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - accuracy: 0.8834 - loss: 0.3496
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - accuracy: 0.8701 - loss: 0.3587
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.8721 - loss: 0.3696
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.8800 - loss: 0.3461
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.9035 - loss: 0.3128
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.8916 - loss: 0.3321
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - accuracy: 0.8975 - loss: 0.3181
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - accuracy: 0.8865 - loss: 0.3384
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.8766 - loss: 0.3446
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - accuracy: 0.8658 - loss: 0.3820
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - accuracy: 0.8819 - loss: 0.3511
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - accuracy: 0.8891 - loss: 0.3351
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.8742 - loss: 0.3541
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - accuracy: 0.8977 - loss: 0.3138
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - accuracy: 0.8997 - loss: 0.3172
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - accuracy: 0.8942 - loss: 0.3242
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - accuracy: 0.9080 - loss: 0.2933
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step - accuracy: 0.8615 - loss: 0.3740
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - accuracy: 0.8914 - loss: 0.3167
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - accuracy: 0.8842 - loss: 0.3337
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - accuracy: 0.8972 - loss: 0.3108
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - accuracy: 0.8818 - loss: 0.3299
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - accuracy: 0.8944 - loss: 0.3001
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - accuracy: 0.9014 - loss: 0.3068
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - accuracy: 0.8964 - loss: 0.3109
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - accuracy: 0.8934 - loss: 0.2979
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - accuracy: 0.8871 - loss: 0.3372
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - accuracy: 0.9028 - loss: 0.2996
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - accuracy: 0.8798 - loss: 0.3366
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - accuracy: 0.8969 - loss: 0.3052
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step - accuracy: 0.9001 - loss: 0.3019
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - accuracy: 0.9002 - loss: 0.2852
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - accuracy: 0.9121 - loss: 0.2740
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - accuracy: 0.8946 - loss: 0.2889
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - accuracy: 0.9040 - loss: 0.2875
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - accuracy: 0.8972 - loss: 0.2922
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - accuracy: 0.8950 - loss: 0.2871
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - accuracy: 0.9034 - loss: 0.2831
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - accuracy: 0.8902 - loss: 0.3005
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - accuracy: 0.8787 - loss: 0.3257
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - accuracy: 0.8950 - loss: 0.2920
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - accuracy: 0.8957 - loss: 0.3095
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - accuracy: 0.9004 - loss: 0.2919
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - accuracy: 0.9088 - loss: 0.2898
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 0.8881 - loss: 0.3060
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step - accuracy: 0.9010 - loss: 0.2767
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.8952 - loss: 0.3154
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - accuracy: 0.8980 - loss: 0.2979
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - accuracy: 0.8894 - loss: 0.2945
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step - accuracy: 0.8836 - loss: 0.3163
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - accuracy: 0.9167 - loss: 0.2408
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - accuracy: 0.8827 - loss: 0.3451
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - accuracy: 0.9058 - loss: 0.2639
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - accuracy: 0.9061 - loss: 0.2834
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.8938 - loss: 0.2948
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - accuracy: 0.8978 - loss: 0.2792
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.9125 - loss: 0.2540
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - accuracy: 0.8965 - loss: 0.2735
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.9023 - loss: 0.2650
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - accuracy: 0.8833 - loss: 0.2992
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - accuracy: 0.9087 - loss: 0.2450
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - accuracy: 0.9172 - loss: 0.2415
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - accuracy: 0.9173 - loss: 0.2386
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - accuracy: 0.9031 - loss: 0.2759
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.9002 - loss: 0.2641
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - accuracy: 0.9045 - loss: 0.2628
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - accuracy: 0.9168 - loss: 0.2452
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.8942 - loss: 0.2824
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.8835 - loss: 0.3023
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.8993 - loss: 0.2589
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.9166 - loss: 0.2482
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.8912 - loss: 0.2856
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - accuracy: 0.9119 - loss: 0.2310
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.9144 - loss: 0.2458
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.9099 - loss: 0.2384
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.8969 - loss: 0.2814
# 8/8 - 0s - 6ms/step - accuracy: 0.8280 - loss: 0.4313
# Loss: 0.4313242435455322, Accuracy: 0.828000009059906

# %%
# Make predictions with the test data
predictions = nn_model.predict(X_test_scaled,verbose=2)
predictions
# Out:
# 8/8 - 0s - 8ms/step
# array([[0.03815341],
#        [0.8745835 ],
#        [0.08948498],
#        [0.0411777 ],
#        [0.07409059],
#        [0.06725916],
#        [0.04045147],
#        [0.78976583],
#        [0.07126686],
#        [0.11594432],
#        [0.38921067],
#        [0.02073904],
#        [0.88166296],
#        [0.13485546],
#        [0.8810704 ],
#        [0.04534651],
#        [0.043904  ],
#        [0.03051418],
#        [0.8768837 ],
#        [0.08225006],
#        [0.4650895 ],
#        [0.11896951],
#        [0.05913428],
#        [0.04051836],
#        [0.0451439 ],
#        [0.05997383],
#        [0.02463361],
#        [0.02183391],
#        [0.04357947],
#        [0.0456701 ],
#        [0.4650895 ],
#        [0.9663629 ],
#        [0.03846406],
#        [0.03169036],
#        [0.02420527],
#        [0.04806503],
#        [0.02623718],
#        [0.99016654],
#        [0.9195305 ],
#        [0.0210583 ],
#        [0.99067336],
#        [0.97688264],
#        [0.05546276],
#        [0.0472107 ],
#        [0.15982132],
#        [0.02286284],
#        [0.05661987],
#        [0.07517902],
#        [0.86539525],
#        [0.920803  ],
#        [0.91912067],
#        [0.03551652],
#        [0.88472307],
#        [0.03624838],
#        [0.03673753],
#        [0.07016379],
#        [0.97051895],
#        [0.98122346],
#        [0.02956637],
#        [0.9495288 ],
#        [0.85015965],
#        [0.8503702 ],
#        [0.04328461],
#        [0.17255925],
#        [0.7164891 ],
#        [0.8865376 ],
#        [0.03574985],
#        [0.09481263],
#        [0.87953544],
#        [0.06116113],
#        [0.93691486],
#        [0.7569139 ],
#        [0.96190757],
#        [0.5086253 ],
#        [0.04248478],
#        [0.05226273],
#        [0.03402751],
#        [0.9256183 ],
#        [0.04691342],
#        [0.19993263],
#        [0.06153239],
#        [0.9640741 ],
#        [0.4650895 ],
#        [0.8411509 ],
#        [0.52024883],
#        [0.04603813],
#        [0.4650895 ],
#        [0.8775712 ],
#        [0.10994828],
#        [0.20018034],
#        [0.97047675],
#        [0.04866569],
#        [0.03763208],
#        [0.8812562 ],
#        [0.03200107],
#        [0.9827764 ],
#        [0.04134753],
#        [0.9002383 ],
#        [0.17970248],
#        [0.7466102 ],
#        [0.1703993 ],
#        [0.08951882],
#        [0.96889687],
#        [0.2687015 ],
#        [0.2312408 ],
#        [0.821072  ],
#        [0.03334621],
#        [0.10298328],
#        [0.03302262],
#        [0.9822605 ],
#        [0.04608417],
#        [0.9721883 ],
#        [0.4650895 ],
#        [0.06794544],
#        [0.764879  ],
#        [0.2021699 ],
#        [0.03545038],
#        [0.03191951],
#        [0.0208433 ],
#        [0.4399084 ],
#        [0.02801619],
#        [0.06151647],
#        [0.05372241],
#        [0.03343169],
#        [0.04561792],
#        [0.92884475],
#        [0.98136723],
#        [0.98188466],
#        [0.5088418 ],
#        [0.97293204],
#        [0.03766252],
#        [0.6326876 ],
#        [0.6976734 ],
#        [0.04962097],
#        [0.8901779 ],
#        [0.889422  ],
#        [0.7930342 ],
#        [0.03376209],
#        [0.04341776],
#        [0.88145363],
#        [0.03515102],
#        [0.04788375],
#        [0.05031582],
#        [0.4650895 ],
#        [0.03457391],
#        [0.04403633],
#        [0.02368398],
#        [0.42028025],
#        [0.04521598],
#        [0.04798689],
#        [0.07896198],
#        [0.06948487],
#        [0.14170082],
#        [0.7577243 ],
#        [0.09037707],
#        [0.8621313 ],
#        [0.58349776],
#        [0.80952984],
#        [0.03670194],
#        [0.03670087],
#        [0.07044514],
#        [0.02559655],
#        [0.05167406],
#        [0.9500219 ],
#        [0.07126684],
#        [0.4650895 ],
#        [0.05591767],
#        [0.84535646],
#        [0.04244174],
#        [0.06262425],
#        [0.4650895 ],
#        [0.4650895 ],
#        [0.03376867],
#        [0.03617277],
#        [0.03110445],
#        [0.06853375],
#        [0.11806816],
#        [0.4650895 ],
#        [0.668657  ],
#        [0.883094  ],
#        [0.18913396],
#        [0.05985303],
#        [0.15247373],
#        [0.96900237],
#        [0.4650895 ],
#        [0.04260365],
#        [0.06347252],
#        [0.03675582],
#        [0.05796085],
#        [0.9901028 ],
#        [0.9831416 ],
#        [0.86826366],
#        [0.03374467],
#        [0.03130827],
#        [0.4998666 ],
#        [0.03300154],
#        [0.9085792 ],
#        [0.06174146],
#        [0.20607285],
#        [0.04350071],
#        [0.03058844],
#        [0.41501474],
#        [0.98730874],
#        [0.03291039],
#        [0.03609692],
#        [0.9910699 ],
#        [0.03718104],
#        [0.03372094],
#        [0.04314008],
#        [0.09521238],
#        [0.89588386],
#        [0.02638945],
#        [0.92814875],
#        [0.02439851],
#        [0.9841331 ],
#        [0.1029887 ],
#        [0.03657822],
#        [0.15580897],
#        [0.0247142 ],
#        [0.06339496],
#        [0.07183104],
#        [0.9733456 ],
#        [0.03941556],
#        [0.22535183],
#        [0.03781282],
#        [0.07115827],
#        [0.1950559 ],
#        [0.6397174 ],
#        [0.94416004],
#        [0.96528363],
#        [0.2832203 ],
#        [0.04086534],
#        [0.4650895 ],
#        [0.4924378 ],
#        [0.95883065],
#        [0.8839193 ],
#        [0.88224196],
#        [0.9847413 ],
#        [0.2626945 ],
#        [0.07627802],
#        [0.03202223],
#        [0.04519018],
#        [0.04518876],
#        [0.9823079 ],
#        [0.19519028],
#        [0.03901034],
#        [0.8993613 ],
#        [0.05382475],
#        [0.0550789 ],
#        [0.03231791]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#      predictions
# 0            0.0
# 1            1.0
# 2            0.0
# 3            0.0
# 4            0.0
# ..           ...
# 245          0.0
# 246          1.0
# 247          0.0
# 248          0.0
# 249          0.0
#
# [250 rows x 1 columns]

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test_encoded, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       157
#            1       0.81      0.70      0.75        93
#
#     accuracy                           0.83       250
#    macro avg       0.82      0.80      0.81       250
# weighted avg       0.83      0.83      0.82       250

# %% [markdown]
# ## Save the Model

# %%
# Set the model's file path
file_path = Path("sports-articles.keras")

# Export your model to a keras file
nn_model.save(file_path)

# %% [markdown]
# ## Load the Model

# %%
# Set the model's file path
file_path = Path("sports-articles.keras")

# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_imported.evaluate(X_test_scaled, y_test_encoded, verbose=2)

# Display evaluation results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - 11ms/step - accuracy: 0.8280 - loss: 0.4313
# Loss: 0.4313242435455322, Accuracy: 0.828000009059906
